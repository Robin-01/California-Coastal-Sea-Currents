# %% [markdown]
# <a href="https://colab.research.google.com/github/Robin-01/California-Coastal-Sea-Currents/blob/main/download_wind.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !echo "machine urs.earthdata.nasa.gov login alexmw password Washington12#$" > ~/.netrc
# !chmod 0600 ~/.netrc

# %%
import os
import requests
from datetime import datetime, timedelta

# Directory to save files
save_dir = "data/ccmp"
os.makedirs(save_dir, exist_ok=True)

# Date range
start_date = datetime(2024, 1, 1)
end_date   = datetime(2024, 12, 31)  # change as needed

# Loop over all dates
date = start_date
while date <= end_date:
    # Construct filename and URL
    filename = f"CCMP_Wind_Analysis_{date.strftime('%Y%m%d')}_V03.1_L4.nc"
    file_path = os.path.join(save_dir, filename)
    url = f"https://data.remss.com/ccmp/v03.1/Y{date.year}/M{date.month:02d}/{filename}"

    # Check if file already exists
    if os.path.exists(file_path):
        print(f"✅ Already have {filename}")
    else:
        print(f"⬇️ Downloading {filename} ...")
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(file_path, "wb") as f:
                for chunk in response.iter_content(chunk_size=8192):
                    f.write(chunk)
            print(f"   ✔ Saved {filename}")
        else:
            print(f"   ❌ Failed to download {filename} (status {response.status_code})")

    # Next day
    date += timedelta(days=1)
# Out:
# ✅ Already have CCMP_Wind_Analysis_20240101_V03.1_L4.nc
# ✅ Already have CCMP_Wind_Analysis_20240102_V03.1_L4.nc
# ✅ Already have CCMP_Wind_Analysis_20240103_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240104_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240104_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240105_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240105_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240106_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240106_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240107_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240107_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240108_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240108_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240109_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240109_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240110_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240110_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240111_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240111_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240112_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240112_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240113_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240113_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240114_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240114_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240115_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240115_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240116_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240116_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240117_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240117_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240118_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240118_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240119_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240119_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240120_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240120_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240121_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240121_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240122_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240122_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240123_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240123_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240124_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240124_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240125_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240125_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240126_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240126_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240127_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240127_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240128_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240128_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240129_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240129_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240130_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240130_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240131_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240131_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240201_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240201_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240202_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240202_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240203_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240203_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240204_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240204_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240205_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240205_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240206_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240206_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240207_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240207_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240208_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240208_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240209_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240209_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240210_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240210_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240211_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240211_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240212_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240212_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240213_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240213_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240214_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240214_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240215_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240215_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240216_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240216_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240217_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240217_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240218_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240218_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240219_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240219_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240220_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240220_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240221_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240221_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240222_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240222_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240223_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240223_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240224_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240224_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240225_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240225_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240226_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240226_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240227_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240227_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240228_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240228_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240229_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240229_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240301_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240301_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240302_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240302_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240303_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240303_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240304_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240304_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240305_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240305_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240306_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240306_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240307_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240307_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240308_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240308_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240309_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240309_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240310_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240310_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240311_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240311_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240312_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240312_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240313_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240313_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240314_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240314_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240315_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240315_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240316_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240316_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240317_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240317_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240318_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240318_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240319_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240319_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240320_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240320_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240321_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240321_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240322_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240322_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240323_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240323_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240324_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240324_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240325_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240325_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240326_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240326_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240327_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240327_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240328_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240328_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240329_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240329_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240330_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240330_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240331_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240331_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240401_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240401_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240402_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240402_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240403_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240403_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240404_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240404_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240405_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240405_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20240406_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20240406_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20
V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241007_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241007_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241008_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241008_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241009_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241009_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241010_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241010_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241011_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241011_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241012_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241012_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241013_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241013_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241014_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241014_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241015_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241015_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241016_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241016_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241017_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241017_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241018_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241018_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241019_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241019_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241020_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241020_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241021_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241021_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241022_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241022_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241023_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241023_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241024_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241024_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241025_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241025_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241026_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241026_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241027_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241027_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241028_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241028_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241029_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241029_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241030_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241030_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241031_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241031_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241101_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241101_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241102_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241102_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241103_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241103_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241104_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241104_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241105_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241105_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241106_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241106_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241107_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241107_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241108_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241108_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241109_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241109_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241110_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241110_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241111_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241111_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241112_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241112_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241113_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241113_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241114_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241114_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241115_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241115_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241116_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241116_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241117_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241117_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241118_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241118_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241119_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241119_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241120_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241120_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241121_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241121_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241122_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241122_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241123_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241123_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241124_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241124_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241125_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241125_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241126_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241126_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241127_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241127_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241128_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241128_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241129_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241129_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241130_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241130_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241201_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241201_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241202_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241202_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241203_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241203_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241204_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241204_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241205_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241205_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241206_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241206_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241207_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241207_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241208_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241208_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241209_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241209_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241210_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241210_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241211_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241211_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241212_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241212_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241213_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241213_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241214_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241214_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241215_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241215_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241216_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241216_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241217_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241217_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241218_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241218_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241219_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241219_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241220_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241220_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241221_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241221_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241222_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241222_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241223_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241223_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241224_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241224_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241225_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241225_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241226_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241226_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241227_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241227_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241228_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241228_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241229_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241229_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241230_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241230_V03.1_L4.nc
# ⬇️ Downloading CCMP_Wind_Analysis_20241231_V03.1_L4.nc ...
#    ✔ Saved CCMP_Wind_Analysis_20241231_V03.1_L4.nc

# %%
import xarray as xr
import os

# Folder where all files are saved
data_dir = '/content/data/ccmp'
# Get a sorted list of all NetCDF files
all_files = sorted([
    os.path.join(data_dir, f)
    for f in os.listdir(data_dir)
    if f.startswith("CCMP_Wind_Analysis_2024") and f.endswith(".nc")
])

print(f"Found {len(all_files)} files for 2024")

# Open all files as one Dataset using xarray and Dask for lazy loading
ds_all = xr.open_mfdataset(
    all_files,
    combine="by_coords",  # combine along coordinates like time
    chunks={"time": 10}   # optional: chunking for large datasets
)

# Inspect the combined dataset
print(ds_all)
# Out:
# Found 366 files for 2024
# <xarray.Dataset> Size: 24GB
# Dimensions:    (time: 1464, latitude: 720, longitude: 1440)
# Coordinates:
#   * latitude   (latitude) float32 3kB -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 6kB 0.125 0.375 0.625 ... 359.4 359.6 359.9
#   * time       (time) datetime64[ns] 12kB 2024-01-01 ... 2024-12-31T18:00:00
# Data variables:
#     uwnd       (time, latitude, longitude) float32 6GB dask.array<chunksize=(4, 720, 1440), meta=np.ndarray>
#     vwnd       (time, latitude, longitude) float32 6GB dask.array<chunksize=(4, 720, 1440), meta=np.ndarray>
#     ws         (time, latitude, longitude) float32 6GB dask.array<chunksize=(4, 720, 1440), meta=np.ndarray>
#     nobs       (time, latitude, longitude) float32 6GB dask.array<chunksize=(4, 720, 1440), meta=np.ndarray>
# Attributes: (12/54)
#     contact:                       Remote Sensing Systems, support@remss.com
#     Conventions:                   CF-1.7 ACDD-1.3
#     data_structure:                grid
#     title:                         RSS CCMP V3.1 6-hourly surface winds (Leve...
#     summary:                       RSS VAM 6-hour analyses using ERA-5 wind r...
#     institute_id:                  RSS
#     ...                            ...
#     time_coverage_end:             2024-01-01T23:59:59Z
#     platform:                      Space-based Platforms>Earth Observation Sa...
#     instrument:                    Earth Remote Sensing Instruments>Passive R...
#     history:                       2024-07-18T13:07:56.387608Z - netCDF gener...
#     base_date:                     Y2024 M01 D01
#     date_created:                  2024-07-18T13:07:56.387608Z

# %%
# !pip install cartopy
# Out:
# Collecting cartopy
#   Downloading cartopy-0.25.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.0.2)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.10.0)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.1.1)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from cartopy) (25.0)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj>=3.3.1->cartopy) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# Downloading cartopy-0.25.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 91.3 MB/s eta 0:00:00
# Installing collected packages: cartopy
# Successfully installed cartopy-0.25.0

# %%
# California bounds
lon_min, lon_max = -131 % 360, -109 % 360  # convert -180..0 to 0..360
lat_min, lat_max = 24, 51

# Crop dataset
ds_ca = ds_all.sel(
    longitude=slice(lon_min, lon_max),
    latitude=slice(lat_min, lat_max)
)

print(ds_ca)


ds_ca
ds_day = ds_ca.sel(time="2024-05-18T12:00", method="nearest")
if ds_day['longitude'].size > 0:
    print(ds_day['uwnd'].min().values)
    print(ds_day['uwnd'].max().values)
    print(ds_day['uwnd'].mean().values)
else:
    print("⚠️ Selection returned empty array")
# Out:
# <xarray.Dataset> Size: 223MB
# Dimensions:    (time: 1464, latitude: 108, longitude: 88)
# Coordinates:
#   * latitude   (latitude) float32 432B 24.12 24.38 24.62 ... 50.38 50.62 50.88
#   * longitude  (longitude) float32 352B 229.1 229.4 229.6 ... 250.4 250.6 250.9
#   * time       (time) datetime64[ns] 12kB 2024-01-01 ... 2024-12-31T18:00:00
# Data variables:
#     uwnd       (time, latitude, longitude) float32 56MB dask.array<chunksize=(4, 108, 88), meta=np.ndarray>
#     vwnd       (time, latitude, longitude) float32 56MB dask.array<chunksize=(4, 108, 88), meta=np.ndarray>
#     ws         (time, latitude, longitude) float32 56MB dask.array<chunksize=(4, 108, 88), meta=np.ndarray>
#     nobs       (time, latitude, longitude) float32 56MB dask.array<chunksize=(4, 108, 88), meta=np.ndarray>
# Attributes: (12/54)
#     contact:                       Remote Sensing Systems, support@remss.com
#     Conventions:                   CF-1.7 ACDD-1.3
#     data_structure:                grid
#     title:                         RSS CCMP V3.1 6-hourly surface winds (Leve...
#     summary:                       RSS VAM 6-hour analyses using ERA-5 wind r...
#     institute_id:                  RSS
#     ...                            ...
#     time_coverage_end:             2024-01-01T23:59:59Z
#     platform:                      Space-based Platforms>Earth Observation Sa...
#     instrument:                    Earth Remote Sensing Instruments>Passive R...
#     history:                       2024-07-18T13:07:56.387608Z - netCDF gener...
#     base_date:                     Y2024 M01 D01
#     date_created:                  2024-07-18T13:07:56.387608Z
# -4.2485743
# 8.819191
# 1.276324

# %%
ds_day = ds_ca.sel(time="2024-05-18")
ds_day = ds_day.isel(time=3)
# Extract u and v wind components
u = ds_day['uwnd']  # zonal (east-west)
v = ds_day['vwnd']  # meridional (north-south)
uwnd_point = ds_day['uwnd'].sel(latitude=35, longitude=-120, method="nearest")
print(uwnd_point.values)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1269355535.py in <cell line: 0>()
#       4 u = ds_day['uwnd']  # zonal (east-west)
#       5 v = ds_day['vwnd']  # meridional (north-south)
# ----> 6 uwnd_point = ds_day['uwnd'].sel(latitude=35, longitude=-120, method="nearest")
#       7 print(uwnd_point.values)
#
# /usr/local/lib/python3.12/dist-packages/xarray/core/dataarray.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1714         Dimensions without coordinates: points
#    1715         """
# -> 1716         ds = self._to_temp_dataset().sel(
#    1717             indexers=indexers,
#    1718             drop=drop,
#
# /usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2989         """
#    2990         indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2991         query_results = map_index_queries(
#    2992             self, indexers=indexers, method=method, tolerance=tolerance
#    2993         )
#
# /usr/local/lib/python3.12/dist-packages/xarray/core/indexing.py in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     199             results.append(IndexSelResult(labels))
#     200         else:
# --> 201             results.append(index.sel(labels, **options))
#     202
#     203     merged = merge_sel_results(results)
#
# /usr/local/lib/python3.12/dist-packages/xarray/core/indexes.py in sel(self, labels, method, tolerance)
#     856                     indexer = get_indexer_nd(self.index, label_array, method, tolerance)
#     857                     if np.any(indexer < 0):
# --> 858                         raise KeyError(f"not all values found in index {coord_name!r}")
#     859                 else:
#     860                     try:
#
# KeyError: "not all values found in index 'longitude'"

# %%
output_path = "/content/drive/MyDrive/wind_california.nc"

# Save compressed NetCDF
ds_ca.to_netcdf(
    output_path,
    mode="w",
    format="NETCDF4",
    engine="netcdf4",
    encoding={var: {"zlib": True, "complevel": 4} for var in ds_ca.data_vars}
)

print(f"Saved to {output_path}")
# Out:
# Saved to /content/drive/MyDrive/wind_california.nc

# %%
# !pip install netCDF4
# Out:
# Collecting netCDF4
#   Downloading netCDF4-1.7.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting cftime (from netCDF4)
#   Downloading cftime-1.6.4.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2025.8.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2.0.2)
# Downloading netCDF4-1.7.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 53.8 MB/s eta 0:00:00
# Downloading cftime-1.6.4.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 49.7 MB/s eta 0:00:00
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.6.4.post1 netCDF4-1.7.2
